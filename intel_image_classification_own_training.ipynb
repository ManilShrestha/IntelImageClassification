# %% [markdown]
# <a href="https://colab.research.google.com/github/ManilShrestha/IntelImageClassification/blob/main/intel_image_classification_own_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 1: Setup Parameters and Variables
# This section imports required libraries and sets up variables that are used throughout the notebook.
# Sets up transformation compositions, loads datasets and defines data loaders for pytorch module.

# %%
# Importing required libraries
from collections import OrderedDict
from torchvision import datasets, transforms, models
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from torch import nn, optim
from PIL import Image
from datetime import datetime

# %%
# Setting up the directory where images are located for three sets: training, validation, testing
# Data are store in google drive. It is mounted to this collab book
training_dir = '/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/seg_train/seg_train'
validation_dir = '/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/seg_val/seg_val'
testing_dir = '/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/seg_test/seg_test'

# %%
# Define transforms for the training, validation, and training sets
# Training data is transformed for rotation and horizontal flip so that it can generalize
training_transforms = transforms.Compose([ transforms.Resize(150)
                                        , transforms.CenterCrop(150)
                                        , transforms.RandomRotation(30)    # Does random 30 degrees rotations
                                        , transforms.RandomHorizontalFlip()  # Does random horizontal flips to the image
                                        , transforms.ToTensor()   # Converts the image into tensor array
                                        , transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])  # Mean and standard deviation, 3 values for the number of channels
                                                                                                         # Values are for the pretrained models from imagenet dataset, using these for transfer learning is okay
                                        ])

validation_transforms = transforms.Compose([ transforms.Resize(150)
                                            , transforms.CenterCrop(150)
                                            , transforms.ToTensor()
                                            , transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
                                            ])

testing_transforms = transforms.Compose([ transforms.Resize(150)
                                         , transforms.CenterCrop(150)
                                         , transforms.ToTensor()
                                         , transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
                                        ])

# %%
# Load the datasets from using datasets.ImageFolder is a generic data loader where the images are arranged in folder structure separated by each class
training_dataset = datasets.ImageFolder(training_dir, transform=training_transforms)
validation_dataset = datasets.ImageFolder(validation_dir, transform = validation_transforms)
test_dataset = datasets.ImageFolder(testing_dir, transform=testing_transforms)

# %%
# Defining dataloaders for training, validation and testing. The batch size determines the number of images sent into model at a time
train_loader = torch.utils.data.DataLoader(training_dataset, batch_size=32, shuffle=True)
validate_loader = torch.utils.data.DataLoader(validation_dataset, batch_size=32)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Section 2: Scratch Learning on VGG16 model
# A pretrained VGG16 model is initialized. Feature parameters are frozen and new classfier network is defined for the DNN.

# %%
# Learning from torchvision's pre given model vgg16
cnn_model = models.vgg16(pretrained=False)
cnn_model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Build a custom classifer that matches output numbers of 6 classes
my_classifier = nn.Sequential(OrderedDict([('Linear1_Transform', nn.Linear(25088, 8000))   # Takes in 25088 input points from the pretrained VGG model, performs linear transformation and gives 8000 output points
                                        , ('ReLU1_Activation', nn.ReLU())              # Rectified Linear Unit activation
                                        , ('Dropout1', nn.Dropout(p = 0.5))            # randomly zeroes some of the elements of the input tensor with probability of 0.5 using samples from a Bernoulli distribution
                                        , ('Linear2_Transform', nn.Linear(8000,6))    # Linear transform, from 8000 input points to 1000 points
                                        # , ('ReLU2_Activation', nn.ReLU())              # Second Rectified Linear Unit activation
                                        # , ('Dropout2', nn.Dropout(p = 0.5))            # randomly zeroes some of the elements of the input tensor with probability of 0.5 using samples from a Bernoulli distribution
                                        # , ('Linear3_Transform', nn.Linear(1000,6))    # Third linear transform, from 1000 input points to 6 points
                                        , ('LogSoftmaxOutput', nn.LogSoftmax(dim=1))  # Log Softmax activation
                                        ]))

cnn_model.classifier = my_classifier    # Assign the newly created classifier as the classifier for the model

cnn_model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (Linear1_Transform): Linear(in_features=25088, out_features=8000, bias=True)
#     (ReLU1_Activation): ReLU()
#     (Dropout1): Dropout(p=0.5, inplace=False)
#     (Linear2_Transform): Linear(in_features=8000, out_features=6, bias=True)
#     (LogSoftmaxOutput): LogSoftmax(dim=1)
#   )
# )

# %% [markdown]
# # Section 3: Loss Functions and Optimizers
# Define loss function to be used in Neural Network. Also, initialize different optimizer functions to be tested as part of the project:
#
# 1.   Stochastic Gradient Descent (SGD)
# 2.   Adaptive Moment Estimation (Adam)
# 3.   Root Mean Square Propagation (RMS Prop)
#
# This section also defines evaluate() function that checks the performance of model on the data passed in validate_loader, based on loss function provided.

# %%
# Loss function definition and gradient descent
loss_function = nn.NLLLoss()                # Negative log likelihood loss function  
sgd_optimizer = optim.SGD(cnn_model.classifier.parameters(),lr = 0.001, momentum=0.9)  # Stochastic Gradient Descent with momentum of 0.9
adam_optimizer = optim.Adam(cnn_model.classifier.parameters(), lr = 0.001)     # Adam is an algorithm for first-order gradient-based optimization of stochastic objective functions, based on adaptive estimates of lower-order moments
rms_prop_optimizer = optim.RMSprop(cnn_model.classifier.parameters(), lr = 0.001) # Implements Adagrad algorithm

# %%
# Evaluation of the model, 
def evaluate(cnn_model, validate_loader, loss_function):

  loss = 0
  accuracy = 0

  for images, labels in iter(validate_loader):
    images, labels = images.to('cuda'), labels.to('cuda')   # To operate on GPU, need to mention CUDA
    
    # Get the output from the given images
    output = cnn_model.forward(images)                # Pass the image batch into model and capture output
    loss += loss_function(output, labels).item()  # Calculate the loss based on the loss_function passed as a parameter

    probability = torch.exp(output)             # Probability is the exponential of output since, output is log softmax

    is_equal = (labels.data == probability.max(dim=1)[1])  # Checks if the labelled data is equal to the model prediction

    accuracy += is_equal.type(torch.FloatTensor).mean()      # Accuracy is sum of mean of equality over the batch sample

  return loss, accuracy

# %%
current_time = datetime.now().strftime("%H:%M:%S")
print("Start Time =", current_time)
for images, labels in iter(train_loader):
  print(labels)
  break

current_time = datetime.now().strftime("%H:%M:%S")
print("End Time =", current_time)
# Out:
# Start Time = 06:03:09
# tensor([3, 3, 4, 4, 3, 0, 5, 2, 4, 2, 1, 2, 3, 5, 2, 3, 2, 0, 0, 2, 3, 3, 1, 2,
#         0, 4, 3, 3, 1, 3, 1, 3])
# End Time = 06:03:27

# %% [markdown]
# There are 6 predefined classes in Intel Image Classification Dataset: Buildings , Forest, Glacier, Mountain, Sea & Street
#
# Training Dataset Size = 14034, Validation Dataset Size = 1200 and Testing Dataset Size = 3000

# %%
# Setting up index and their actual names
# %pwd
import json
with open('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/class_index.json', 'r') as f:
  class_names = json.load(f)

print("Total Class: ", len(class_names),"\n", class_names)
print("\nTraining Data Size: ", len(training_dataset))
print("Validation Data Size: ", len(validation_dataset))
print("Testing Data Size: ", len(test_dataset))
# Out:
# Total Class:  6
#  {'0': 'buildings', '1': 'forest', '2': 'glacier', '3': 'mountain', '4': 'sea', '5': 'street'}
#
# Training Data Size:  14034
# Validation Data Size:  1200
# Testing Data Size:  3000

# %% [markdown]
# # Section 4: Train Classifier
# This section trains the classifier based on training data set, evaluates the performance on validation data and training data. To train this model, a GPU session needs to be activated (Runtime -> Change runtime type).
#
# If you have a pretrained pytorch model on Intel Image Classification dataset, please skip this part. Go to **Section 5: Classify images**

# %%
# This function saves the trained model so that retraining is not required everytime classifier needs to be used.
def save_trained_model(cnn_model, filepath):

  # Storing actual class name and the indices created by pytorch for the model training
  cnn_model.class_to_idx = training_dataset.class_to_idx

  # Model info as dictionary
  model_info = {'architecture':"vgg16"
                , 'class_to_idx': cnn_model.class_to_idx
                , 'model_state_dict': cnn_model.state_dict()
                }
  torch.save(model_info, filepath)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Jun  4 06:03:42 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
cnn_loss_dict = dict()

# Lists to hold metadata on loss and accuracy to analyze the convergence
adam_validation_loss = []
adam_accuracy = []
sgd_validation_loss = []
sgd_accuracy = []
rmsprop_validation_loss = []
rmsprop_accuracy = []

# %% [markdown]
# ## Adam Optimizer

# %%
# Adam Optmizer:
# Run time: 14:32:41 - 14:18:22 = 0:24:19
# Epoch size: 20
# This function trains the model based on training data
def train_classifier_adam():
  # Set up hyper parameters
  total_epochs = 20
  steps = 0

  # Training start time
  current_time = datetime.now().strftime("%H:%M:%S")
  print("Start Time =", current_time)

  cnn_model.to('cuda')    # Making the model run on GPU
  
  for epoch in range(total_epochs):   # Will iterate through epochs
    cnn_model.train()         # Set model to training mode
    cumulative_loss = 0     # This variable stores the total loss for each epoch until it is printed

    for image_batch, label_batch in iter(train_loader):
      steps += 1
      #print(steps)
      image_batch, label_batch = image_batch.to('cuda'), label_batch.to('cuda')
      adam_optimizer.zero_grad()     # we need to set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes

      output = cnn_model.forward(image_batch)  # Pass the image batch into model
      loss = loss_function(output, label_batch)  # It is a NLLLoss, a negative log likelihood loss function

      loss.backward()   # loss.backward() computes dloss/dx for every parameter x which has requires_grad=True. These are accumulated into x.grad for every parameter x.
      adam_optimizer.step()  # optimizer.step performs a parameter update based on the current gradient (stored in .grad attribute of a parameter) and the update rule

      cumulative_loss += loss.item()    # item() method extracts the loss’s value as a Python float. Cumulative loss accumulates sum of running loss over each epoch

      # if steps%25 == 0:
      #   print("Batch Running: {}".format(steps * 64))

    cnn_model.eval()      # Turn model into evaluation mode
    
    # Turning off gradients for evaluation of the model
    with torch.no_grad():
      validation_loss, accuracy = evaluate(cnn_model, validate_loader, loss_function)     # Based on parameters passed, calculate validation loss and accuracy on validation dataset

      print("Epoch: {} of {}".format(epoch + 1, total_epochs),                                 # Epoch number
      "Training NLL Loss: {:.3f}".format(cumulative_loss/len(train_loader)),                 # Average training loss
      "Validation NLL Loss: {:.3f}".format(validation_loss/len(validate_loader)),   # Average validation loss: validation loss divided by total validation data set size
      "Validation Accuracy: {:.3f}".format(accuracy/len(validate_loader)))      # Average accuracy
      
      # Appending training metadata for analysis
      adam_validation_loss.append(validation_loss/len(validate_loader))
      adam_accuracy.append(accuracy/len(validate_loader))

      cumulative_loss = 0    # Reset running loss
      cnn_model.train()       # Turn back training mode

    steps = 0
  # Training end time
  current_time = datetime.now().strftime("%H:%M:%S")
  print("End Time =", current_time)

train_classifier_adam()

# Saving the trained CNN model into file 
save_trained_model(cnn_model,'/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/own_vgg16_adam_trained.data')
# Out:
# Start Time = 22:40:42
# Epoch: 1 of 20 Training NLL Loss: 1.818 Validation NLL Loss: 1.206 Validation Accuracy: 0.523
# Epoch: 2 of 20 Training NLL Loss: 1.318 Validation NLL Loss: 1.214 Validation Accuracy: 0.557
# Epoch: 3 of 20 Training NLL Loss: 1.322 Validation NLL Loss: 1.186 Validation Accuracy: 0.556
# Epoch: 4 of 20 Training NLL Loss: 1.348 Validation NLL Loss: 1.166 Validation Accuracy: 0.594
# Epoch: 5 of 20 Training NLL Loss: 1.318 Validation NLL Loss: 1.147 Validation Accuracy: 0.578
# Epoch: 6 of 20 Training NLL Loss: 1.286 Validation NLL Loss: 1.239 Validation Accuracy: 0.499
# Epoch: 7 of 20 Training NLL Loss: 1.286 Validation NLL Loss: 1.078 Validation Accuracy: 0.602
# Epoch: 8 of 20 Training NLL Loss: 1.269 Validation NLL Loss: 1.199 Validation Accuracy: 0.557
# Epoch: 9 of 20 Training NLL Loss: 1.279 Validation NLL Loss: 1.118 Validation Accuracy: 0.574
# Epoch: 10 of 20 Training NLL Loss: 1.241 Validation NLL Loss: 1.066 Validation Accuracy: 0.598
# Epoch: 11 of 20 Training NLL Loss: 1.237 Validation NLL Loss: 1.156 Validation Accuracy: 0.573
# Epoch: 12 of 20 Training NLL Loss: 1.227 Validation NLL Loss: 1.083 Validation Accuracy: 0.586
# Epoch: 13 of 20 Training NLL Loss: 1.224 Validation NLL Loss: 1.102 Validation Accuracy: 0.596
# Epoch: 14 of 20 Training NLL Loss: 1.216 Validation NLL Loss: 1.038 Validation Accuracy: 0.608
# Epoch: 15 of 20 Training NLL Loss: 1.202 Validation NLL Loss: 1.080 Validation Accuracy: 0.603
# Epoch: 16 of 20 Training NLL Loss: 1.200 Validation NLL Loss: 1.075 Validation Accuracy: 0.603
# Epoch: 17 of 20 Training NLL Loss: 1.199 Validation NLL Loss: 1.046 Validation Accuracy: 0.630
# Epoch: 18 of 20 Training NLL Loss: 1.197 Validation NLL Loss: 1.025 Validation Accuracy: 0.627
# Epoch: 19 of 20 Training NLL Loss: 1.190 Validation NLL Loss: 1.124 Validation Accuracy: 0.562
# Epoch: 20 of 20 Training NLL Loss: 1.202 Validation NLL Loss: 1.011 Validation Accuracy: 0.637
# End Time = 23:16:20

# %% [markdown]
# ## Reset the CNN model

# %%
# Learning from torchvision's pre given model vgg16
cnn_model = models.vgg16(pretrained=False)
cnn_model

# Build a custom classifer
my_classifier = nn.Sequential(OrderedDict([('Linear1_Transform', nn.Linear(25088, 8000))   # Takes in 25088 input points from the pretrained VGG model, performs linear transformation and gives 8000 output points
                                        , ('ReLU1_Activation', nn.ReLU())              # Rectified Linear Unit activation
                                        , ('Dropout1', nn.Dropout(p = 0.5))            # randomly zeroes some of the elements of the input tensor with probability of 0.5 using samples from a Bernoulli distribution
                                        , ('Linear2_Transform', nn.Linear(8000,6))    # Linear transform, from 8000 input points to 1000 points
                                        # , ('ReLU2_Activation', nn.ReLU())              # Second Rectified Linear Unit activation
                                        # , ('Dropout2', nn.Dropout(p = 0.5))            # randomly zeroes some of the elements of the input tensor with probability of 0.5 using samples from a Bernoulli distribution
                                        # , ('Linear3_Transform', nn.Linear(1000,6))    # Third linear transform, from 1000 input points to 6 points
                                        , ('LogSoftmaxOutput', nn.LogSoftmax(dim=1))  # Log Softmax activation
                                        ]))

cnn_model.classifier = my_classifier    # Assign the newly created classifier as the classifier for the model

# Loss function definition and gradient descent
loss_function = nn.NLLLoss()                # Negative log likelihood loss function  
sgd_optimizer = optim.SGD(cnn_model.classifier.parameters(),lr = 0.001, momentum=0.9)  # Stochastic Gradient Descent with momentum of 0.9
adam_optimizer = optim.Adam(cnn_model.classifier.parameters(), lr = 0.001)     # Adam is an algorithm for first-order gradient-based optimization of stochastic objective functions, based on adaptive estimates of lower-order moments
rms_prop_optimizer = optim.RMSprop(cnn_model.classifier.parameters(), lr = 0.001) # Implements Adagrad algorithm

# %% [markdown]
# ## Train SGD

# %%
# SGD Optmizer: 
# Run time: 
# Epoch size: 20
# This function trains the model based on training data
def train_classifier_sgd():
  # Set up hyper parameters
  total_epochs = 200
  steps = 0

  # Training start time
  current_time = datetime.now().strftime("%H:%M:%S")
  print("Start Time =", current_time)

  cnn_model.to('cuda')    # Making the model run on GPU
  
  for epoch in range(total_epochs):   # Will iterate through epochs
    cnn_model.train()         # Set model to training mode
    cumulative_loss = 0     # This variable stores the total loss for each epoch until it is printed

    for image_batch, label_batch in iter(train_loader):
      steps += 1
      #print(steps)
      image_batch, label_batch = image_batch.to('cuda'), label_batch.to('cuda')
      sgd_optimizer.zero_grad()     # we need to set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes

      output = cnn_model.forward(image_batch)  # Pass the image batch into model
      loss = loss_function(output, label_batch)  # It is a NLLLoss, a negative log likelihood loss function

      loss.backward()   # loss.backward() computes dloss/dx for every parameter x which has requires_grad=True. These are accumulated into x.grad for every parameter x.
      sgd_optimizer.step()  # optimizer.step performs a parameter update based on the current gradient (stored in .grad attribute of a parameter) and the update rule

      cumulative_loss += loss.item()    # item() method extracts the loss’s value as a Python float. Cumulative loss accumulates sum of running loss over each epoch

      # if steps%10 == 0:
      #   print("Batch Running: {}".format(steps * 32))

    cnn_model.eval()      # Turn model into evaluation mode
    
    # Turning off gradients for evaluation of the model
    with torch.no_grad():
      validation_loss, accuracy = evaluate(cnn_model, validate_loader, loss_function)     # Based on parameters passed, calculate validation loss and accuracy on validation dataset

      print("Epoch: {} of {}".format(epoch + 1, total_epochs),                                 # Epoch number
      "Training NLL Loss: {:.3f}".format(cumulative_loss/len(train_loader)),                 # Average training loss
      "Validation NLL Loss: {:.3f}".format(validation_loss/len(validate_loader)),   # Average validation loss: validation loss divided by total validation data set size
      "Validation Accuracy: {:.3f}".format(accuracy/len(validate_loader)))      # Average accuracy
      
      # Appending training metadata for analysis
      sgd_validation_loss.append(validation_loss/len(validate_loader))
      sgd_accuracy.append(accuracy/len(validate_loader))

      cumulative_loss = 0    # Reset running loss
      cnn_model.train()       # Turn back training mode

    steps = 0
  # Training end time
  current_time = datetime.now().strftime("%H:%M:%S")
  print("End Time =", current_time)

train_classifier_sgd()

# Saving the trained CNN model into file 
save_trained_model(cnn_model,'/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/own_vgg16_sgd_trained.data')
# Out:
# Start Time = 23:18:18
# Epoch: 1 of 20 Training NLL Loss: 1.566 Validation NLL Loss: 1.450 Validation Accuracy: 0.388
# Epoch: 2 of 20 Training NLL Loss: 1.332 Validation NLL Loss: 1.299 Validation Accuracy: 0.467
# Epoch: 3 of 20 Training NLL Loss: 1.259 Validation NLL Loss: 1.226 Validation Accuracy: 0.525
# Epoch: 4 of 20 Training NLL Loss: 1.214 Validation NLL Loss: 1.180 Validation Accuracy: 0.553
# Epoch: 5 of 20 Training NLL Loss: 1.190 Validation NLL Loss: 1.127 Validation Accuracy: 0.578
# Epoch: 6 of 20 Training NLL Loss: 1.161 Validation NLL Loss: 1.098 Validation Accuracy: 0.588
# Epoch: 7 of 20 Training NLL Loss: 1.151 Validation NLL Loss: 1.091 Validation Accuracy: 0.588
# Epoch: 8 of 20 Training NLL Loss: 1.140 Validation NLL Loss: 1.115 Validation Accuracy: 0.576
# Epoch: 9 of 20 Training NLL Loss: 1.139 Validation NLL Loss: 1.094 Validation Accuracy: 0.567
# Epoch: 10 of 20 Training NLL Loss: 1.130 Validation NLL Loss: 1.114 Validation Accuracy: 0.576
# Epoch: 11 of 20 Training NLL Loss: 1.114 Validation NLL Loss: 1.080 Validation Accuracy: 0.582
# Epoch: 12 of 20 Training NLL Loss: 1.115 Validation NLL Loss: 1.098 Validation Accuracy: 0.556
# Epoch: 13 of 20 Training NLL Loss: 1.114 Validation NLL Loss: 1.128 Validation Accuracy: 0.562
# Epoch: 14 of 20 Training NLL Loss: 1.112 Validation NLL Loss: 1.046 Validation Accuracy: 0.591
# Epoch: 15 of 20 Training NLL Loss: 1.090 Validation NLL Loss: 1.014 Validation Accuracy: 0.619
# Epoch: 16 of 20 Training NLL Loss: 1.091 Validation NLL Loss: 1.074 Validation Accuracy: 0.584
# Epoch: 17 of 20 Training NLL Loss: 1.085 Validation NLL Loss: 1.022 Validation Accuracy: 0.611
# Epoch: 18 of 20 Training NLL Loss: 1.076 Validation NLL Loss: 1.017 Validation Accuracy: 0.600
# Epoch: 19 of 20 Training NLL Loss: 1.079 Validation NLL Loss: 1.119 Validation Accuracy: 0.565
# Epoch: 20 of 20 Training NLL Loss: 1.072 Validation NLL Loss: 1.068 Validation Accuracy: 0.586
# End Time = 23:51:12

# %% [markdown]
# ## Reset CNN

# %%
# Learning from torchvision's pre given model vgg16
cnn_model = models.vgg16(pretrained=False)
cnn_model

# Build a custom classifer
my_classifier = nn.Sequential(OrderedDict([('Linear1_Transform', nn.Linear(25088, 8000))   # Takes in 25088 input points from the pretrained VGG model, performs linear transformation and gives 8000 output points
                                        , ('ReLU1_Activation', nn.ReLU())              # Rectified Linear Unit activation
                                        , ('Dropout1', nn.Dropout(p = 0.5))            # randomly zeroes some of the elements of the input tensor with probability of 0.5 using samples from a Bernoulli distribution
                                        , ('Linear2_Transform', nn.Linear(8000,6))    # Linear transform, from 8000 input points to 1000 points
                                        # , ('ReLU2_Activation', nn.ReLU())              # Second Rectified Linear Unit activation
                                        # , ('Dropout2', nn.Dropout(p = 0.5))            # randomly zeroes some of the elements of the input tensor with probability of 0.5 using samples from a Bernoulli distribution
                                        # , ('Linear3_Transform', nn.Linear(1000,6))    # Third linear transform, from 1000 input points to 6 points
                                        , ('LogSoftmaxOutput', nn.LogSoftmax(dim=1))  # Log Softmax activation
                                        ]))

cnn_model.classifier = my_classifier    # Assign the newly created classifier as the classifier for the model

# Loss function definition and gradient descent
loss_function = nn.NLLLoss()                # Negative log likelihood loss function  
sgd_optimizer = optim.SGD(cnn_model.classifier.parameters(),lr = 0.001, momentum=0.9)  # Stochastic Gradient Descent with momentum of 0.9
adam_optimizer = optim.Adam(cnn_model.classifier.parameters(), lr = 0.001)     # Adam is an algorithm for first-order gradient-based optimization of stochastic objective functions, based on adaptive estimates of lower-order moments
rms_prop_optimizer = optim.RMSprop(cnn_model.classifier.parameters(), lr = 0.001) # Implements Adagrad algorithm

# %% [markdown]
# ## Train RMS Prop

# %%
# RMSProp Optmizer:
# Run time: 16:04:11 - 15:52:51 = 0:11:20
# Epoch size: 10
# This function trains the model based on training data
def train_classifier_rmsprop():
  # Set up hyper parameters
  total_epochs = 200
  steps = 0

  # Training start time
  current_time = datetime.now().strftime("%H:%M:%S")
  print("Start Time =", current_time)

  cnn_model.to('cuda')    # Making the model run on GPU
  
  for epoch in range(total_epochs):   # Will iterate through epochs
    cnn_model.train()         # Set model to training mode
    cumulative_loss = 0     # This variable stores the total loss for each epoch until it is printed

    for image_batch, label_batch in iter(train_loader):
      steps += 1
      #print(steps)
      image_batch, label_batch = image_batch.to('cuda'), label_batch.to('cuda')
      rms_prop_optimizer.zero_grad()     # we need to set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes

      output = cnn_model.forward(image_batch)  # Pass the image batch into model
      loss = loss_function(output, label_batch)  # It is a NLLLoss, a negative log likelihood loss function

      loss.backward()   # loss.backward() computes dloss/dx for every parameter x which has requires_grad=True. These are accumulated into x.grad for every parameter x.
      rms_prop_optimizer.step()  # optimizer.step performs a parameter update based on the current gradient (stored in .grad attribute of a parameter) and the update rule

      cumulative_loss += loss.item()    # item() method extracts the loss’s value as a Python float. Cumulative loss accumulates sum of running loss over each epoch

      # if steps%25 == 0:
      #   print("Batch Running: {}".format(steps * 32))

    cnn_model.eval()      # Turn model into evaluation mode
    
    # Turning off gradients for evaluation of the model
    with torch.no_grad():
      validation_loss, accuracy = evaluate(cnn_model, validate_loader, loss_function)     # Based on parameters passed, calculate validation loss and accuracy on validation dataset

      print("Epoch: {} of {}".format(epoch + 1, total_epochs),                                 # Epoch number
      "Training NLL Loss: {:.3f}".format(cumulative_loss/len(train_loader)),                 # Average training loss
      "Validation NLL Loss: {:.3f}".format(validation_loss/len(validate_loader)),   # Average validation loss: validation loss divided by total validation data set size
      "Validation Accuracy: {:.3f}".format(accuracy/len(validate_loader)))      # Average accuracy
      
      # Appending training metadata for analysis
      rmsprop_validation_loss.append(validation_loss/len(validate_loader))
      rmsprop_accuracy.append(accuracy/len(validate_loader))

      cumulative_loss = 0    # Reset running loss
      cnn_model.train()       # Turn back training mode

    steps = 0
  # Training end time
  current_time = datetime.now().strftime("%H:%M:%S")
  print("End Time =", current_time)

train_classifier_rmsprop()

# Saving the trained CNN model into file 
save_trained_model(cnn_model,'/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/own_vgg16_rmsprop_trained.data')
# Out:
# Start Time = 06:04:46
# Epoch: 1 of 200 Training NLL Loss: 7.628 Validation NLL Loss: 1.330 Validation Accuracy: 0.472
# Epoch: 2 of 200 Training NLL Loss: 1.343 Validation NLL Loss: 1.219 Validation Accuracy: 0.531
# Epoch: 3 of 200 Training NLL Loss: 1.285 Validation NLL Loss: 1.326 Validation Accuracy: 0.466
# Epoch: 4 of 200 Training NLL Loss: 1.252 Validation NLL Loss: 1.249 Validation Accuracy: 0.496
# Epoch: 5 of 200 Training NLL Loss: 1.232 Validation NLL Loss: 1.164 Validation Accuracy: 0.554
# Epoch: 6 of 200 Training NLL Loss: 1.205 Validation NLL Loss: 1.113 Validation Accuracy: 0.549
# Epoch: 7 of 200 Training NLL Loss: 1.197 Validation NLL Loss: 1.065 Validation Accuracy: 0.567
# Epoch: 8 of 200 Training NLL Loss: 1.186 Validation NLL Loss: 1.077 Validation Accuracy: 0.557
# Epoch: 9 of 200 Training NLL Loss: 1.164 Validation NLL Loss: 1.133 Validation Accuracy: 0.548
# Epoch: 10 of 200 Training NLL Loss: 1.161 Validation NLL Loss: 1.041 Validation Accuracy: 0.606
# Epoch: 11 of 200 Training NLL Loss: 1.157 Validation NLL Loss: 1.075 Validation Accuracy: 0.586
# Epoch: 12 of 200 Training NLL Loss: 1.140 Validation NLL Loss: 1.041 Validation Accuracy: 0.600
# Epoch: 13 of 200 Training NLL Loss: 1.128 Validation NLL Loss: 1.029 Validation Accuracy: 0.585
# Epoch: 14 of 200 Training NLL Loss: 1.124 Validation NLL Loss: 0.993 Validation Accuracy: 0.609
# Epoch: 15 of 200 Training NLL Loss: 1.125 Validation NLL Loss: 1.045 Validation Accuracy: 0.609
# Epoch: 16 of 200 Training NLL Loss: 1.119 Validation NLL Loss: 1.025 Validation Accuracy: 0.594
# Epoch: 17 of 200 Training NLL Loss: 1.104 Validation NLL Loss: 0.980 Validation Accuracy: 0.600
# Epoch: 18 of 200 Training NLL Loss: 1.100 Validation NLL Loss: 0.972 Validation Accuracy: 0.616
# Epoch: 19 of 200 Training NLL Loss: 1.090 Validation NLL Loss: 0.951 Validation Accuracy: 0.645
# Epoch: 20 of 200 Training NLL Loss: 1.086 Validation NLL Loss: 1.015 Validation Accuracy: 0.595
# Epoch: 21 of 200 Training NLL Loss: 1.080 Validation NLL Loss: 0.983 Validation Accuracy: 0.601
# Epoch: 22 of 200 Training NLL Loss: 1.071 Validation NLL Loss: 0.912 Validation Accuracy: 0.662
# Epoch: 23 of 200 Training NLL Loss: 1.070 Validation NLL Loss: 0.904 Validation Accuracy: 0.667
# Epoch: 24 of 200 Training NLL Loss: 1.068 Validation NLL Loss: 0.947 Validation Accuracy: 0.651
# Epoch: 25 of 200 Training NLL Loss: 1.053 Validation NLL Loss: 1.006 Validation Accuracy: 0.586
# Epoch: 26 of 200 Training NLL Loss: 1.065 Validation NLL Loss: 0.896 Validation Accuracy: 0.665
# Epoch: 27 of 200 Training NLL Loss: 1.056 Validation NLL Loss: 0.885 Validation Accuracy: 0.657
# Epoch: 28 of 200 Training NLL Loss: 1.047 Validation NLL Loss: 0.921 Validation Accuracy: 0.643
# Epoch: 29 of 200 Training NLL Loss: 1.048 Validation NLL Loss: 0.928 Validation Accuracy: 0.655
# Epoch: 30 of 200 Training NLL Loss: 1.045 Validation NLL Loss: 1.030 Validation Accuracy: 0.595
# Epoch: 31 of 200 Training NLL Loss: 1.040 Validation NLL Loss: 0.915 Validation Accuracy: 0.661
# Epoch: 32 of 200 Training NLL Loss: 1.040 Validation NLL Loss: 0.907 Validation Accuracy: 0.656
# Epoch: 33 of 200 Training NLL Loss: 1.022 Validation NLL Loss: 0.965 Validation Accuracy: 0.634
# Epoch: 34 of 200 Training NLL Loss: 1.022 Validation NLL Loss: 0.954 Validation Accuracy: 0.623
# Epoch: 35 of 200 Training NLL Loss: 1.025 Validation NLL Loss: 0.949 Validation Accuracy: 0.640
# Epoch: 36 of 200 Training NLL Loss: 1.020 Validation NLL Loss: 0.936 Validation Accuracy: 0.638
# Epoch: 37 of 200 Training NLL Loss: 1.009 Validation NLL Loss: 0.893 Validation Accuracy: 0.660
# Epoch: 38 of 200 Training NLL Loss: 1.025 Validation NLL Loss: 0.860 Validation Accuracy: 0.681
# Epoch: 39 of 200 Training NLL Loss: 1.023 Validation NLL Loss: 0.958 Validation Accuracy: 0.637
# Epoch: 40 of 200 Training NLL Loss: 1.009 Validation NLL Loss: 0.849 Validation Accuracy: 0.676
# Epoch: 41 of 200 Training NLL Loss: 1.009 Validation NLL Loss: 0.871 Validation Accuracy: 0.669
# Epoch: 42 of 200 Training NLL Loss: 1.004 Validation NLL Loss: 0.882 Validation Accuracy: 0.681
# Epoch: 43 of 200 Training NLL Loss: 0.995 Validation NLL Loss: 0.923 Validation Accuracy: 0.646
# Epoch: 44 of 200 Training NLL Loss: 1.002 Validation NLL Loss: 0.891 Validation Accuracy: 0.679
# Epoch: 45 of 200 Training NLL Loss: 0.990 Validation NLL Loss: 0.923 Validation Accuracy: 0.660
# Epoch: 46 of 200 Training NLL Loss: 1.009 Validation NLL Loss: 0.863 Validation Accuracy: 0.686
# Epoch: 47 of 200 Training NLL Loss: 0.985 Validation NLL Loss: 0.880 Validation Accuracy: 0.655
# Epoch: 48 of 200 Training NLL Loss: 0.992 Validation NLL Loss: 0.845 Validation Accuracy: 0.683
# Epoch: 49 of 200 Training NLL Loss: 0.989 Validation NLL Loss: 0.943 Validation Accuracy: 0.629
# Epoch: 50 of 200 Training NLL Loss: 0.995 Validation NLL Loss: 0.904 Validation Accuracy: 0.656
# Epoch: 51 of 200 Training NLL Loss: 0.984 Validation NLL Loss: 0.831 Validation Accuracy: 0.690
# Epoch: 52 of 200 Training NLL Loss: 0.982 Validation NLL Loss: 0.871 Validation Accuracy: 0.669
# Epoch: 53 of 200 Training NLL Loss: 0.989 Validation NLL Loss: 0.850 Validation Accuracy: 0.677
# Epoch: 54 of 200 Training NLL Loss: 0.973 Validation NLL Loss: 0.878 Validation Accuracy: 0.653
# Epoch: 55 of 200 Training NLL Loss: 0.978 Validation NLL Loss: 0.932 Validation Accuracy: 0.644
# Epoch: 56 of 200 Training NLL Loss: 0.971 Validation NLL Loss: 0.894 Validation Accuracy: 0.668
# Epoch: 57 of 200 Training NLL Loss: 0.976 Validation NLL Loss: 0.867 Validation Accuracy: 0.678
# Epoch: 58 of 200 Training NLL Loss: 0.975 Validation NLL Loss: 0.873 Validation Accuracy: 0.667
# Epoch: 59 of 200 Training NLL Loss: 0.960 Validation NLL Loss: 0.984 Validation Accuracy: 0.630
# Epoch: 60 of 200 Training NLL Loss: 0.976 Validation NLL Loss: 0.856 Validation Accuracy: 0.665
# Epoch: 61 of 200 Training NLL Loss: 0.964 Validation NLL Loss: 1.010 Validation Accuracy: 0.627
# Epoch: 62 of 200 Training NLL Loss: 0.970 Validation NLL Loss: 0.968 Validation Accuracy: 0.642
# Epoch: 63 of 200 Training NLL Loss: 0.976 Validation NLL Loss: 0.863 Validation Accuracy: 0.673
# Epoch: 64 of 200 Training NLL Loss: 0.961 Validation NLL Loss: 0.865 Validation Accuracy: 0.654
# Epoch: 65 of 200 Training NLL Loss: 0.963 Validation NLL Loss: 0.850 Validation Accuracy: 0.688
# Epoch: 66 of 200 Training NLL Loss: 0.962 Validation NLL Loss: 0.814 Validation Accuracy: 0.694
# Epoch: 67 of 200 Training NLL Loss: 0.961 Validation NLL Loss: 0.845 Validation Accuracy: 0.683
# Epoch: 68 of 200 Training NLL Loss: 0.962 Validation NLL Loss: 0.909 Validation Accuracy: 0.639
# Epoch: 69 of 200 Training NLL Loss: 0.968 Validation NLL Loss: 0.835 Validation Accuracy: 0.680
# Epoch: 70 of 200 Training NLL Loss: 0.955 Validation NLL Loss: 1.020 Validation Accuracy: 0.583
# Epoch: 71 of 200 Training NLL Loss: 0.952 Validation NLL Loss: 0.872 Validation Accuracy: 0.679
# Epoch: 72 of 200 Training NLL Loss: 0.954 Validation NLL Loss: 0.871 Validation Accuracy: 0.667
# Epoch: 73 of 200 Training NLL Loss: 0.956 Validation NLL Loss: 0.913 Validation Accuracy: 0.650
# Epoch: 74 of 200 Training NLL Loss: 0.949 Validation NLL Loss: 0.825 Validation Accuracy: 0.688
# Epoch: 75 of 200 Training NLL Loss: 0.949 Validation NLL Loss: 0.853 Validation Accuracy: 0.674
# Epoch: 76 of 200 Training NLL Loss: 0.952 Validation NLL Loss: 0.857 Validation Accuracy: 0.666
# Epoch: 77 of 200 Training NLL Loss: 0.952 Validation NLL Loss: 0.828 Validation Accuracy: 0.689
# Epoch: 78 of 200 Training NLL Loss: 0.946 Validation NLL Loss: 0.812 Validation Accuracy: 0.696
# Epoch: 79 of 200 Training NLL Loss: 0.950 Validation NLL Loss: 0.841 Validation Accuracy: 0.666
# Epoch: 80 of 200 Training NLL Loss: 0.942 Validation NLL Loss: 0.827 Validation Accuracy: 0.685
# Epoch: 81 of 200 Training NLL Loss: 0.955 Validation NLL Loss: 0.813 Validation Accuracy: 0.705
# Epoch: 82 of 200 Training NLL Loss: 0.938 Validation NLL Loss: 0.816 Validation Accuracy: 0.686
# Epoch: 83 of 200 Training NLL Loss: 0.953 Validation NLL Loss: 0.816 Validation Accuracy: 0.691
# Epoch: 84 of 200 Training NLL Loss: 0.945 Validation NLL Loss: 0.806 Validation Accuracy: 0.704
# Epoch: 85 of 200 Training NLL Loss: 0.938 Validation NLL Loss: 0.848 Validation Accuracy: 0.679
# Epoch: 86 of 200 Training NLL Loss: 0.936 Validation NLL Loss: 0.818 Validation Accuracy: 0.687
# Epoch: 87 of 200 Training NLL Loss: 0.943 Validation NLL Loss: 0.794 Validation Accuracy: 0.695
# Epoch: 88 of 200 Training NLL Loss: 0.928 Validation NLL Loss: 0.820 Validation Accuracy: 0.689
# Epoch: 89 of 200 Training NLL Loss: 0.930 Validation NLL Loss: 0.861 Validation Accuracy: 0.664
# Epoch: 90 of 200 Training NLL Loss: 0.942 Validation NLL Loss: 0.809 Validation Accuracy: 0.700
# Epoch: 91 of 200 Training NLL Loss: 0.929 Validation NLL Loss: 0.835 Validation Accuracy: 0.695
# Epoch: 92 of 200 Training NLL Loss: 0.938 Validation NLL Loss: 0.815 Validation Accuracy: 0.695
# Epoch: 93 of 200 Training NLL Loss: 0.936 Validation NLL Loss: 0.812 Validation Accuracy: 0.712
# Epoch: 94 of 200 Training NLL Loss: 0.929 Validation NLL Loss: 0.868 Validation Accuracy: 0.672
# Epoch: 95 of 200 Training NLL Loss: 0.935 Validation NLL Loss: 0.843 Validation Accuracy: 0.682
# Epoch: 96 of 200 Training NLL Loss: 0.929 Validation NLL Loss: 0.784 Validation Accuracy: 0.711
# Epoch: 97 of 200 Training NLL Loss: 0.929 Validation NLL Loss: 0.864 Validation Accuracy: 0.685
# Epoch: 98 of 200 Training NLL Loss: 0.935 Validation NLL Loss: 0.842 Validation Accuracy: 0.687
# Epoch: 99 of 200 Training NLL Loss: 0.918 Validation NLL Loss: 0.889 Validation Accuracy: 0.678
# Epoch: 100 of 200 Training NLL Loss: 0.929 Validation NLL Loss: 0.817 Validation Accuracy: 0.697
# Epoch: 101 of 200 Training NLL Loss: 0.933 Validation NLL Loss: 0.838 Validation Accuracy: 0.678
# Epoch: 102 of 200 Training NLL Loss: 0.921 Validation NLL Loss: 0.821 Validation Accuracy: 0.672
# Epoch: 103 of 200 Training NLL Loss: 0.926 Validation NLL Loss: 0.781 Validation Accuracy: 0.701
# Epoch: 104 of 200 Training NLL Loss: 0.923 Validation NLL Loss: 0.870 Validation Accuracy: 0.669
# Epoch: 105 of 200 Training NLL Loss: 0.923 Validation NLL Loss: 0.799 Validation Accuracy: 0.692
# Epoch: 106 of 200 Training NLL Loss: 0.919 Validation NLL Loss: 0.803 Validation Accuracy: 0.692
# Epoch: 107 of 200 Training NLL Loss: 0.920 Validation NLL Loss: 0.782 Validation Accuracy: 0.697
# Epoch: 108 of 200 Training NLL Loss: 0.926 Validation NLL Loss: 0.822 Validation Accuracy: 0.684
# Epoch: 109 of 200 Training NLL Loss: 0.920 Validation NLL Loss: 0.842 Validation Accuracy: 0.693
# Epoch: 110 of 200 Training NLL Loss: 0.919 Validation NLL Loss: 0.875 Validation Accuracy: 0.680
# Epoch: 111 of 200 Training NLL Loss: 0.924 Validation NLL Loss: 0.821 Validation Accuracy: 0.694
# Epoch: 112 of 200 Training NLL Loss: 0.908 Validation NLL Loss: 0.847 Validation Accuracy: 0.663
# Epoch: 113 of 200 Training NLL Loss: 0.917 Validation NLL Loss: 0.832 Validation Accuracy: 0.695
# Epoch: 114 of 200 Training NLL Loss: 0.918 Validation NLL Loss: 0.828 Validation Accuracy: 0.674
# Epoch: 115 of 200 Training NLL Loss: 0.909 Validation NLL Loss: 0.994 Validation Accuracy: 0.605
# Epoch: 116 of 200 Training NLL Loss: 0.917 Validation NLL Loss: 0.780 Validation Accuracy: 0.701
# Epoch: 117 of 200 Training NLL Loss: 0.910 Validation NLL Loss: 0.801 Validation Accuracy: 0.710
# Epoch: 118 of 200 Training NLL Loss: 0.906 Validation NLL Loss: 0.835 Validation Accuracy: 0.682
# Epoch: 119 of 200 Training NLL Loss: 0.917 Validation NLL Loss: 0.810 Validation Accuracy: 0.682
# Epoch: 120 of 200 Training NLL Loss: 0.899 Validation NLL Loss: 0.821 Validation Accuracy: 0.696
# Epoch: 121 of 200 Training NLL Loss: 0.908 Validation NLL Loss: 0.846 Validation Accuracy: 0.690
# Epoch: 122 of 200 Training NLL Loss: 0.908 Validation NLL Loss: 0.882 Validation Accuracy: 0.677
# Epoch: 123 of 200 Training NLL Loss: 0.918 Validation NLL Loss: 0.808 Validation Accuracy: 0.691
# Epoch: 124 of 200 Training NLL Loss: 0.904 Validation NLL Loss: 0.818 Validation Accuracy: 0.689
# Epoch: 125 of 200 Training NLL Loss: 0.914 Validation NLL Loss: 0.766 Validation Accuracy: 0.701
# Epoch: 126 of 200 Training NLL Loss: 0.903 Validation NLL Loss: 0.775 Validation Accuracy: 0.705
# Epoch: 127 of 200 Training NLL Loss: 0.900 Validation NLL Loss: 0.820 Validation Accuracy: 0.691
# Epoch: 128 of 200 Training NLL Loss: 0.899 Validation NLL Loss: 0.797 Validation Accuracy: 0.714
# Epoch: 129 of 200 Training NLL Loss: 0.907 Validation NLL Loss: 0.837 Validation Accuracy: 0.702
# Epoch: 130 of 200 Training NLL Loss: 0.914 Validation NLL Loss: 1.083 Validation Accuracy: 0.613
# Epoch: 131 of 200 Training NLL Loss: 0.912 Validation NLL Loss: 0.793 Validation Accuracy: 0.684
# Epoch: 132 of 200 Training NLL Loss: 0.905 Validation NLL Loss: 0.890 Validation Accuracy: 0.677
# Epoch: 133 of 200 Training NLL Loss: 0.901 Validation NLL Loss: 0.794 Validation Accuracy: 0.692
# Epoch: 134 of 200 Training NLL Loss: 0.888 Validation NLL Loss: 0.787 Validation Accuracy: 0.700
# Epoch: 135 of 200 Training NLL Loss: 0.909 Validation NLL Loss: 0.813 Validation Accuracy: 0.694
# Epoch: 136 of 200 Training NLL Loss: 0.900 Validation NLL Loss: 0.837 Validation Accuracy: 0.694
# Epoch: 137 of 200 Training NLL Loss: 0.890 Validation NLL Loss: 0.778 Validation Accuracy: 0.691
# Epoch: 138 of 200 Training NLL Loss: 0.895 Validation NLL Loss: 0.781 Validation Accuracy: 0.709
# Epoch: 139 of 200 Training NLL Loss: 0.903 Validation NLL Loss: 0.771 Validation Accuracy: 0.716
# Epoch: 140 of 200 Training NLL Loss: 0.896 Validation NLL Loss: 0.851 Validation Accuracy: 0.680
# Epoch: 141 of 200 Training NLL Loss: 0.894 Validation NLL Loss: 0.852 Validation Accuracy: 0.670
# Epoch: 142 of 200 Training NLL Loss: 0.903 Validation NLL Loss: 0.833 Validation Accuracy: 0.693
# Epoch: 143 of 200 Training NLL Loss: 0.894 Validation NLL Loss: 0.789 Validation Accuracy: 0.705
# Epoch: 144 of 200 Training NLL Loss: 0.897 Validation NLL Loss: 0.829 Validation Accuracy: 0.672
# Epoch: 145 of 200 Training NLL Loss: 0.894 Validation NLL Loss: 0.778 Validation Accuracy: 0.706
# Epoch: 146 of 200 Training NLL Loss: 0.895 Validation NLL Loss: 0.790 Validation Accuracy: 0.702
# Epoch: 147 of 200 Training NLL Loss: 0.895 Validation NLL Loss: 0.787 Validation Accuracy: 0.713
# Epoch: 148 of 200 Training NLL Loss: 0.895 Validation NLL Loss: 0.920 Validation Accuracy: 0.650
# Epoch: 149 of 200 Training NLL Loss: 0.888 Validation NLL Loss: 0.805 Validation Accuracy: 0.701
# Epoch: 150 of 200 Training NLL Loss: 0.880 Validation NLL Loss: 0.811 Validation Accuracy: 0.691
# Epoch: 151 of 200 Training NLL Loss: 0.880 Validation NLL Loss: 0.883 Validation Accuracy: 0.682
# Epoch: 152 of 200 Training NLL Loss: 0.898 Validation NLL Loss: 0.781 Validation Accuracy: 0.707
# Epoch: 153 of 200 Training NLL Loss: 0.899 Validation NLL Loss: 0.760 Validation Accuracy: 0.717
# Epoch: 154 of 200 Training NLL Loss: 0.895 Validation NLL Loss: 0.819 Validation Accuracy: 0.689
# Epoch: 155 of 200 Training NLL Loss: 0.888 Validation NLL Loss: 0.793 Validation Accuracy: 0.706
# Epoch: 156 of 200 Training NLL Loss: 0.889 Validation NLL Loss: 0.779 Validation Accuracy: 0.711
# Epoch: 157 of 200 Training NLL Loss: 0.887 Validation NLL Loss: 0.822 Validation Accuracy: 0.695
# Epoch: 158 of 200 Training NLL Loss: 0.888 Validation NLL Loss: 0.783 Validation Accuracy: 0.724
# Epoch: 159 of 200 Training NLL Loss: 0.875 Validation NLL Loss: 0.767 Validation Accuracy: 0.715
# Epoch: 160 of 200 Training NLL Loss: 0.883 Validation NLL Loss: 0.790 Validation Accuracy: 0.720
# Epoch: 161 of 200 Training NLL Loss: 0.888 Validation NLL Loss: 0.833 Validation Accuracy: 0.680
# Epoch: 162 of 200 Training NLL Loss: 0.873 Validation NLL Loss: 0.798 Validation Accuracy: 0.702
# Epoch: 163 of 200 Training NLL Loss: 0.894 Validation NLL Loss: 0.776 Validation Accuracy: 0.703
# Epoch: 164 of 200 Training NLL Loss: 0.888 Validation NLL Loss: 0.769 Validation Accuracy: 0.718
# Epoch: 165 of 200 Training NLL Loss: 0.878 Validation NLL Loss: 0.790 Validation Accuracy: 0.709
# Epoch: 166 of 200 Training NLL Loss: 0.892 Validation NLL Loss: 0.830 Validation Accuracy: 0.669
# Epoch: 167 of 200 Training NLL Loss: 0.880 Validation NLL Loss: 0.797 Validation Accuracy: 0.699
# Epoch: 168 of 200 Training NLL Loss: 0.878 Validation NLL Loss: 0.806 Validation Accuracy: 0.707
# Epoch: 169 of 200 Training NLL Loss: 0.884 Validation NLL Loss: 0.775 Validation Accuracy: 0.715
# Epoch: 170 of 200 Training NLL Loss: 0.886 Validation NLL Loss: 0.796 Validation Accuracy: 0.707
# Epoch: 171 of 200 Training NLL Loss: 0.880 Validation NLL Loss: 0.768 Validation Accuracy: 0.712
# Epoch: 172 of 200 Training NLL Loss: 0.879 Validation NLL Loss: 0.819 Validation Accuracy: 0.686
# Epoch: 173 of 200 Training NLL Loss: 0.883 Validation NLL Loss: 0.845 Validation Accuracy: 0.688
# Epoch: 174 of 200 Training NLL Loss: 0.879 Validation NLL Loss: 0.806 Validation Accuracy: 0.701
# Epoch: 175 of 200 Training NLL Loss: 0.878 Validation NLL Loss: 0.765 Validation Accuracy: 0.713
# Epoch: 176 of 200 Training NLL Loss: 0.872 Validation NLL Loss: 0.810 Validation Accuracy: 0.699
# Epoch: 177 of 200 Training NLL Loss: 0.884 Validation NLL Loss: 0.832 Validation Accuracy: 0.693
# Epoch: 178 of 200 Training NLL Loss: 0.871 Validation NLL Loss: 0.792 Validation Accuracy: 0.693
# Epoch: 179 of 200 Training NLL Loss: 0.875 Validation NLL Loss: 0.821 Validation Accuracy: 0.712
# Epoch: 180 of 200 Training NLL Loss: 0.877 Validation NLL Loss: 0.819 Validation Accuracy: 0.696
# Epoch: 181 of 200 Training NLL Loss: 0.876 Validation NLL Loss: 0.765 Validation Accuracy: 0.715
# Epoch: 182 of 200 Training NLL Loss: 0.871 Validation NLL Loss: 0.801 Validation Accuracy: 0.701
# Epoch: 183 of 200 Training NLL Loss: 0.878 Validation NLL Loss: 0.768 Validation Accuracy: 0.719
# Epoch: 184 of 200 Training NLL Loss: 0.870 Validation NLL Loss: 0.818 Validation Accuracy: 0.705
# Epoch: 185 of 200 Training NLL Loss: 0.880 Validation NLL Loss: 0.822 Validation Accuracy: 0.702
# Epoch: 186 of 200 Training NLL Loss: 0.868 Validation NLL Loss: 0.795 Validation Accuracy: 0.694
# Epoch: 187 of 200 Training NLL Loss: 0.868 Validation NLL Loss: 0.805 Validation Accuracy: 0.698
# Epoch: 188 of 200 Training NLL Loss: 0.874 Validation NLL Loss: 0.816 Validation Accuracy: 0.694
# Epoch: 189 of 200 Training NLL Loss: 0.863 Validation NLL Loss: 0.864 Validation Accuracy: 0.685
# Epoch: 190 of 200 Training NLL Loss: 0.878 Validation NLL Loss: 0.852 Validation Accuracy: 0.680
# Epoch: 191 of 200 Training NLL Loss: 0.870 Validation NLL Loss: 0.784 Validation Accuracy: 0.700
# Epoch: 192 of 200 Training NLL Loss: 0.876 Validation NLL Loss: 0.809 Validation Accuracy: 0.725
# Epoch: 193 of 200 Training NLL Loss: 0.868 Validation NLL Loss: 0.799 Validation Accuracy: 0.689
# Epoch: 194 of 200 Training NLL Loss: 0.876 Validation NLL Loss: 0.917 Validation Accuracy: 0.664
# Epoch: 195 of 200 Training NLL Loss: 0.868 Validation NLL Loss: 0.759 Validation Accuracy: 0.725
# Epoch: 196 of 200 Training NLL Loss: 0.867 Validation NLL Loss: 0.790 Validation Accuracy: 0.706
# Epoch: 197 of 200 Training NLL Loss: 0.877 Validation NLL Loss: 0.768 Validation Accuracy: 0.715
# Epoch: 198 of 200 Training NLL Loss: 0.867 Validation NLL Loss: 0.790 Validation Accuracy: 0.706
# Epoch: 199 of 200 Training NLL Loss: 0.870 Validation NLL Loss: 0.836 Validation Accuracy: 0.683
# Epoch: 200 of 200 Training NLL Loss: 0.862 Validation NLL Loss: 0.832 Validation Accuracy: 0.696
# End Time = 13:30:27

# %% [markdown]
# ### Accuracy of the model
# accuracy_test() measures the accuracy of the trained model. This is done to check how well the model performs on previously unseen test data.

# %%
# Similar to validation() function. But does not calculate loss on the training set.. Just the accuracy of model on test data
# Run stats: 
def accuracy_test(cnn_model, test_loader):

    # Do validation on the test set
    # Setting to evaluation mode
    cnn_model.eval()

    # Changing model to run on GPU
    cnn_model.to('cuda')

    # Turning off gradients for evaluation of the model
    with torch.no_grad():
    
        accuracy = 0
    
        for images, labels in iter(test_loader):
            images, labels = images.to('cuda'), labels.to('cuda')
            output = cnn_model.forward(images)
            probability = torch.exp(output)      # Since last activation is log softmax, need to raise into exponent to get probability
            is_equal = (labels.data == probability.max(dim=1)[1])
            accuracy += is_equal.type(torch.FloatTensor).mean()   # Cumulative mean accuracy per batch
        
        print("Test Accuracy: {}".format(accuracy/len(test_loader)))    
        
        
accuracy_test(cnn_model, test_loader)
# Out:
# Test Accuracy: 0.5872119069099426

# %% [markdown]
# ## Section 5: Classify Images
# Before classifying an image based on trained model. Load the model file using load_trained_model() function. This function loads the model data file which is located at filepath and is passed as parameter.
#
# After the trained model is loaded as cnn_model, we can proceed to classify images using image_classification() function. Where you can pass the path where image is located and can see what are the prediction classes and probabilities for predictions in bar graph.

# %%
# Function that loads and rebuilds the saved model. We need to save the model so that there are no 

def load_trained_model(filepath):
    
    saved_model = torch.load(filepath)
    
    cnn_model = models.vgg16(pretrained=False)

    cnn_model.class_to_idx = saved_model['class_to_idx']
    
    my_classifier = nn.Sequential(OrderedDict([('Linear1_Transform', nn.Linear(25088, 8000))   # Takes in 25088 input points from the pretrained VGG model, performs linear transformation and gives 8000 output points
                                        , ('ReLU1_Activation', nn.ReLU())              # Rectified Linear Unit activation
                                        , ('Dropout1', nn.Dropout(p = 0.5))            # randomly zeroes some of the elements of the input tensor with probability of 0.5 using samples from a Bernoulli distribution
                                        , ('Linear2_Transform', nn.Linear(8000,6))    # Linear transform, from 8000 input points to 1000 points
                                        # , ('ReLU2_Activation', nn.ReLU())              # Second Rectified Linear Unit activation
                                        # , ('Dropout2', nn.Dropout(p = 0.5))            # randomly zeroes some of the elements of the input tensor with probability of 0.5 using samples from a Bernoulli distribution
                                        # , ('Linear3_Transform', nn.Linear(1000,6))    # Third linear transform, from 1000 input points to 6 points
                                        , ('LogSoftmaxOutput', nn.LogSoftmax(dim=1))  # Log Softmax activation
                                        ]))
    cnn_model.classifier = my_classifier
    
    cnn_model.load_state_dict(saved_model['model_state_dict'])
    
    return cnn_model

cnn_model = load_trained_model('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/own_vgg16_rmsprop_trained.data')
print(cnn_model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (Linear1_Transform): Linear(in_features=25088, out_features=8000, bias=True)
#     (ReLU1_Activation): ReLU()
#     (Dropout1): Dropout(p=0.5, inplace=False)
#     (Linear2_Transform): Linear(in_features=8000, out_features=6, bias=True)
#     (LogSoftmaxOutput): LogSoftmax(dim=1)
#   )
# )

# %%
def process_image(image_path):
  ''' Scales, crops, and normalizes a PIL image for a PytTorch model. Preprocessing needs to be identical to the training sets.
   '''
  image = Image.open(image_path)
  #print(image)

  # Resize, thumbnail maintains aspect ratio, first changing the size to 200 by 200
  image.thumbnail((150,150))
  print(image)
  # Now cropping so that the size is 150*150 as the training data set
  margin_l = (image.width - 150)/2   #  Get the crop start at left
  margin_r = margin_l + 150
  margin_b = (image.height - 150)/2  # Get the crop start at bottom
  margin_t = margin_b + 150

  image = image.crop((margin_l, margin_b, margin_r, margin_t))

  # Normalize so that the original 0-255 range is between 0-1
  np_image = np.array(image)/255

  # Z scoring the image pixel range so that it matches the training dataset std and mean
  mean = np.array([0.485, 0.456, 0.406])
  std = np.array([0.229, 0.224, 0.225])
  np_image = (np_image - mean) / std   # z score

  # Pytorch needs the channel to be the first element in the array but PIL image has channel as third dimension. Re-arranges the numpy array
  np_image = np_image.transpose((2,0,1))

  return np_image

# %%
def display_image(image, axis = None):
  if axis is None:
    figure, axis = plt.subplots()
  # Rearranging the array so that channel is 3 dimension.. Pytorch as channel in first element of the arry, matplotlib has it as third element
  image = image.transpose((1,2,0))

  # Undo z scoring to get actual pixel values in 0-1 range
  mean = np.array([0.485,0.456,0.406])
  std = np.array([0.229,0.224,0.225])
  image = image * std + mean

  axis.imshow(image)

  return axis

# %%
def classify (image_path, model):
  '''
  Predict the class of an image using a trained deep learning model
  '''
  # Load the image in path to get numpy array
  image = process_image(image_path)

  # Convert the numpy array to PyTorch tensor
  image = torch.from_numpy(image).type(torch.FloatTensor)

  # Adds an additional dimension to the tensor
  image = image.unsqueeze(0)
  # Pass the image tensor to the model
  output = model.forward(image)

  # Get the probabilites by exponential, since the output is log softmax, need to exp to get accurate output probability
  probabilities = torch.exp(output)

  top_prediction_prob, top_indices = probabilities.topk(6)

  #print(probabilities.topk(6))
  # Get probabilities and ranking tensor predicted by the model
  top_predictions_tensor = top_prediction_prob.detach().type(torch.FloatTensor)
  top_index_rank_tensor = top_indices.detach().type(torch.FloatTensor)

  # Convert tensors into lists
  top_predictions = top_predictions_tensor.numpy().tolist()[0]
  top_index_rank = top_index_rank_tensor.numpy().tolist()[0]

  # print(model.class_to_idx)
  # for key , value in model.class_to_idx.items():
  #   print(key, value)

  # change class-index mapping to index-class mapping so that it can be used to identify the actual class name from index
  index_class = {value: key for key , value in model.class_to_idx.items()}

  classifications = [index_class[index] for index in top_index_rank]

  return top_predictions, classifications

# classification_prob, classes = classify('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/seg_pred/seg_pred/952.jpg', cnn_model)

prediction_prob, classifications = classify('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/mountain.jpg', cnn_model)
print(prediction_prob)
print(classifications)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x104 at 0x7F3FC07A5FD0>
# [0.6371914148330688, 0.2083577960729599, 0.13975386321544647, 0.012881076894700527, 0.001637830981053412, 0.00017793312144931406]
# ['glacier', 'mountain', 'sea', 'buildings', 'street', 'forest']

# %%
def image_classification(imagepath, model):
  plt.figure(figsize=(10,10))
  plt_a = plt.subplot(2,1,1)
  given_image = process_image(imagepath)

  display_image(given_image, plt_a)

  # Classify the given image 
  prediction_prob, classifications = classify(imagepath, model)

  # Show bar chart with probability values
  plt.subplot(2,1,2)
  sns.set_theme(style="white", context="talk")
  sns.barplot(x=prediction_prob, y=classifications, palette="deep" )

# %% [markdown]
# Now we use the trained model to classify the images from my camera and few from the web.

# %%
image_classification('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/street_1.jpg', cnn_model)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x84 at 0x7F3FB4E4D4D0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x84 at 0x7F3FB4E4DA50>

# %%
image_classification('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/896.jpg', cnn_model)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x7F3FB4DFCC10>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x7F3FB355CC90>

# %%
image_classification('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/2235.jpg', cnn_model)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x7F3FB34BB290>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x7F3FB34BB810>

# %%
image_classification('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/drexel_garden.jpg', cnn_model)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x113 at 0x7F3FB3392090>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x113 at 0x7F3FB3392550>

# %%
image_classification('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/cars_buildings.jpg', cnn_model)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x113 at 0x7F3FB32E7850>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x113 at 0x7F3FB32E7D10>

# %%
image_classification('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/thailand.jpg', cnn_model)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x128 at 0x7F3FB31C0A10>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x128 at 0x7F3FB31C0ED0>

# %%
image_classification('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/forest.jpg', cnn_model)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x100 at 0x7F3FB3118710>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x100 at 0x7F3FB3118C90>

# %%
image_classification('/content/drive/MyDrive/ColabNotebooks/IntelImageClassification/mountain.jpg', cnn_model)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x104 at 0x7F3FB3070890>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x104 at 0x7F3FB3070CD0>

# %% [markdown]
# ## Accuracy by epochs

# %%
rmsprop_validation_accuracy = torch.stack(rmsprop_accuracy).numpy()
sgd_validation_accuracy = torch.stack(sgd_accuracy).numpy()
adam_validation_accuracy = torch.stack(adam_accuracy).numpy()

plt.figure(figsize=(10,5))
plt.plot(np.arange(1, len(sgd_validation_accuracy)+1),sgd_validation_accuracy, label='sgd')
plt.plot(np.arange(1, len(adam_validation_accuracy)+1),adam_validation_accuracy, label='adam')
plt.plot(np.arange(1, len(rmsprop_validation_accuracy)+1),rmsprop_validation_accuracy, label='rms prop')
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.title('Accuracy by Epoch')
plt.legend()

# %% [markdown]
# ## Perfomance on training

# %%
# create a dataset
timings = [32.9,35.633,33.8833]
bars = ('SGD', 'Adam', 'RMS Prop')
x_pos = np.arange(len(bars))

# Create bars with different colors
plt.bar(x_pos, timings, color = ['#1f77b4','orange','#60b760'])

# Create names on the x-axis
plt.xticks(x_pos, bars)

plt.xlabel('Optimization Techniques')
plt.ylabel('Time taken (mins)')
plt.title('Training time for 20 epochs')

# Show graph
plt.show()

# %%
# rmsprop_accuracy = torch.stack(rmsprop_accuracy).numpy()
plt.figure(figsize=(10,5))

plt.plot(np.arange(1,len(rmsprop_accuracy)+1),rmsprop_accuracy, label='rms prop')
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.title('Accuracy by Epoch')
plt.legend()
